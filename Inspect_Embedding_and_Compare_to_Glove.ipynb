# %% [markdown]
# # Inspect Embedding and Compare to Glove

# %%
#imports 
import json
import numpy as np
import pandas as pd
from scipy.spatial import distance_matrix as get_dm

# %%
# functions to load embeddings from file

def load_embedding_from_json(file_path:str):    
    with open(file_path,"r",encoding="utf-8") as json_file:
         word_embedding = json.load(json_file)       
    # convert vectors from list to np array
    for key, vector in word_embedding.items():
        word_embedding[key] = np.array(vector)
    return word_embedding

def load_glove_embedding_from_file(file_path):
    df = pd.read_csv(file_path, sep=" ", quoting=3, header=None, index_col=0)
    glove = {key: val.values for key, val in df.T.items()}
    return glove

# %%
# load open api embedding 
api_embedding = load_embedding_from_json("saved_embeddings/open_api_embedding_5d_314_words.json")

# %%
#load glove embedding
glove_embedding = load_glove_embedding_from_file("saved_embeddings/glove.6B.50d.txt")

# %% [markdown]
# ### Reduce Glove Embedding to same Vocabulary as OpenAPI Embedding

# %%
def extract_words_and_vectors_from_embedding(embedding: dict):
    words = []
    vectors = []
    
    for word, vector in embedding.items():
        words.append(word)
        vectors.append(vector)
    
    return words, np.array(vectors)

# %%
api_embedding_words, api_embedding_vectors = extract_words_and_vectors_from_embedding(api_embedding)

# %%
def reduce_embedding_to_words(embedding: dict, words: list):
    reduced_embedding = {}
    for w in words:
        try:
            vector = embedding[w]
            reduced_embedding[w] = vector
        except:
            pass
    return reduced_embedding

# %%
# reduce glove embedding to the same words as api embedding
glove_embedding = reduce_embedding_to_words(glove_embedding, api_embedding_words)

# %%
print("Size own embedding: "+str(len(api_embedding)))
print("Size glove embedding: "+str(len(glove_embedding)))
# Out:
# Size own embedding: 314
# Size glove embedding: 311

# %%
glove_embedding_words, glove_embedding_vectors = extract_words_and_vectors_from_embedding(glove_embedding)

# %%
api_embedding_distance_matrix = get_dm(api_embedding_vectors,api_embedding_vectors)

# %%
glove_embedding_distance_matrix = get_dm(glove_embedding_vectors, glove_embedding_vectors)

# %% [markdown]
# # Closest words

# %%
def get_nearest_words(word:str, distance_matrix, words: list):
    index_word = -1
    for i, w in enumerate(words):
        if w == word:
            index_word = i
            break
    if index_word == -1:
        msg = "error: word "+str(word)+" is not embedded"
        print(msg)
        return msg 
    wordpair_distances = [] # list of ["word", "other_word", distance]
    for i, dist in enumerate(distance_matrix[index_word]):
        other_word = words[i]
        dist = distance_matrix[index_word][i]
            
        wordpair_distances.append([word, other_word, dist])
    
    def sort_comparer(e):
        return e[2]
            
    wordpair_distances.sort(key=sort_comparer)
    
    return wordpair_distances

# %% [markdown]
# <h2>Check Word </h2>

# %%
word_to_check = "owner"
number_to_show = 10

# %%
# nearest words open api embedding
nearest_words_api_embedding = get_nearest_words(word_to_check, api_embedding_distance_matrix, api_embedding_words)

print("nearest words in api embedding are: ")
nearest_words_api_embedding[:number_to_show]
# Out:
# nearest words in api embedding are:
# [['owner', 'owner', 0.0],
#  ['owner', 'file', 1.1714972951960434],
#  ['owner', 'event', 1.4067387042686557],
#  ['owner', 'settings', 1.4684077833552351],
#  ['owner', 'events', 1.4998481322402601],
#  ['owner', 'default', 1.5868387233692043],
#  ['owner', 'user', 1.657490680034519],
#  ['owner', 'attributes', 1.7983961547964487],
#  ['owner', 'links', 1.8745989960425573],
#  ['owner', 'self', 1.9856773481001821]]

# %%
# nearest words glove embedding
nearest_words_glove_embedding = get_nearest_words(word_to_check, glove_embedding_distance_matrix, glove_embedding_words)

print("nearest words in glove embedding are: ")
nearest_words_glove_embedding[:number_to_show]
# Out:
# nearest words in glove embedding are:
# [['owner', 'owner', 0.0],
#  ['owner', 'name', 4.256417422285671],
#  ['owner', 'parent', 4.347656112098677],
#  ['owner', 'client', 4.378706726525105],
#  ['owner', 'instance', 4.475563292100783],
#  ['owner', 'managed', 4.487743598502036],
#  ['owner', 'brand', 4.53856056674856],
#  ['owner', 'exception', 4.555435206668623],
#  ['owner', 'has', 4.645052051693285],
#  ['owner', 'merchant', 4.684459211227589]]

# %% [markdown]
# # Show closest words to every word

# %%
# get 5 closest words to every word

number_closest_words = 5

for word in api_embedding_words:
    closest_api_embedding = get_nearest_words(word, api_embedding_distance_matrix, api_embedding_words)[1:number_closest_words+1]
    try:
        closest_api_embedding = [i[1] for i in closest_api_embedding]
    except:
        pass
    
    closest_glove_embedding = get_nearest_words(word, glove_embedding_distance_matrix, glove_embedding_words)[1:number_closest_words+1]
    try:
        closest_glove_embedding = [i[1] for i in closest_glove_embedding]
    except:
        pass
    
    print("word: "+word)
    print("closest API embedding:   "+str(closest_api_embedding))
    print("closest GloVe embedding: "+str(closest_glove_embedding))
    print()
# Out:
# word: action
# closest API embedding:   ['client', 'request', 'policy', 'account', 'from']
# closest GloVe embedding: ['response', 'result', 'set', 'to', 'charge']
#
# word: account
# closest API embedding:   ['client', 'email', 'action', 'message', 'errors']
# closest GloVe embedding: ['accounts', 'instance', 'value', 'expense', 'claims']
#
# word: id
# closest API embedding:   ['name', 'group', 'type', 'code', 'error']
# closest GloVe embedding: ['tags', 'card', 'info', 'addresses', 'url']
#
# word: request
# closest API embedding:   ['client', 'action', 'update', 'settings', 'account']
# closest GloVe embedding: ['charge', 'to', 'instance', 'allowed', 'exception']
#
# word: user
# closest API embedding:   ['created', 'default', 'size', 'parent', 'url']
# closest GloVe embedding: ['users', 'web', 'addresses', 'available', 'client']
#
# word: resource
# closest API embedding:   ['version', 'api', 'properties', 'providers', 'subscription']
# closest GloVe embedding: ['resources', 'source', 'availability', 'fields', 'repository']
#
# word: item
# closest API embedding:   ['fields', 'class', 'items', 'has', 'custom']
# closest GloVe embedding: ['items', 'exception', 'instance', 'reference', 'addresses']
#
# word: version
# closest API embedding:   ['resource', 'api', 'id', 'next', 'name']
# closest GloVe embedding: ['versions', 'format', 'name', 'instance', 'label']
#
# word: type
# closest API embedding:   ['name', 'code', 'id', 'description', 'status']
# closest GloVe embedding: ['instance', 'element', 'modified', 'is', 'exception']
#
# word: result
# closest API embedding:   ['template', 'label', 'set', 'image', 'request']
# closest GloVe embedding: ['following', 'instance', 'exception', 'of', 'time']
#
# word: message
# closest API embedding:   ['group', 'error', 'code', 'target', 'groups']
# closest GloVe embedding: ['messages', 'address', 'speech', 'reference', 'warning']
#
# word: status
# closest API embedding:   ['description', 'data', 'type', 'code', 'key']
# closest GloVe embedding: ['exception', 'relation', 'instance', 'mandate', 'order']
#
# word: content
# closest API embedding:   ['modified', 'is', 'parent', 'created', 'default']
# closest GloVe embedding: ['available', 'product', 'instance', 'source', 'reference']
#
# word: filter
# closest API embedding:   ['token', 'tags', 'tag', 'version', 'count']
# closest GloVe embedding: ['template', 'method', 'tags', 'content', 'embedded']
#
# word: created
# closest API embedding:   ['url', 'last', 'user', 'content', 'is']
# closest GloVe embedding: ['instance', 'by', 'included', 'of', 'exception']
#
# word: at
# closest API embedding:   ['updated', 'order', 'to', 'number', 'in']
# closest GloVe embedding: ['in', 'from', 'next', 'time', 'to']
#
# word: description
# closest API embedding:   ['status', 'data', 'type', 'state', 'code']
# closest GloVe embedding: ['reference', 'detail', 'instance', 'exception', 'relation']
#
# word: items
# closest API embedding:   ['has', 'custom', 'item', 'image', 'text']
# closest GloVe embedding: ['item', 'available', 'purchases', 'instance', 'names']
#
# word: name
# closest API embedding:   ['id', 'type', 'code', 'group', 'value']
# closest GloVe embedding: ['is', 'names', 'instance', 'exception', 'created']
#
# word: updated
# closest API embedding:   ['total', 'title', 'order', 'url', 'at']
# closest GloVe embedding: ['update', 'available', 'page', 'date', 'sets']
#
# error: word uuid is not embedded
# word: uuid
# closest API embedding:   ['creator', 'avatar', 'alias', 'whitelist', 'batch']
# closest GloVe embedding: rror:
#
# word: category
# closest API embedding:   ['first', 'country', 'order', 'number', 'rate']
# closest GloVe embedding: ['class', 'exception', 'instance', 'sets', 'element']
#
# word: last
# closest API embedding:   ['date', 'url', 'is', 'created', 'order']
# closest GloVe embedding: ['next', 'end', 'in', 'following', 'first']
#
# word: by
# closest API embedding:   ['date', 'title', 'url', 'is', 'last']
# closest GloVe embedding: ['from', 'has', 'created', 'included', 'following']
#
# word: state
# closest API embedding:   ['data', 'description', 'value', 'status', 'type']
# closest GloVe embedding: ['in', 'country', 'of', 'has', 'to']
#
# word: title
# closest API embedding:   ['by', 'url', 'is', 'updated', 'total']
# closest GloVe embedding: ['first', 'player', 'time', 'play', 'event']
#
# error: word href is not embedded
# word: href
# closest API embedding:   ['meta', 'related', 'rel', 'warnings', 'available']
# closest GloVe embedding: rror:
#
# word: fields
# closest API embedding:   ['class', 'item', 'custom', 'messages', 'items']
# closest GloVe embedding: ['resources', 'field', 'created', 'other', 'of']
#
# word: label
# closest API embedding:   ['template', 'result', 'image', 'schedule', 'event']
# closest GloVe embedding: ['band', 'album', 'brand', 'created', 'release']
#
# word: section
# closest API embedding:   ['draft', 'coordinates', 'color', 'web', 'teams']
# closest GloVe embedding: ['sections', 'main', 'in', 'exception', 'instance']
#
# word: value
# closest API embedding:   ['location', 'group', 'type', 'state', 'code']
# closest GloVe embedding: ['amount', 'account', 'price', 'values', 'assets']
#
# word: sections
# closest API embedding:   ['pages', 'teams', 'modified', 'draft', 'app']
# closest GloVe embedding: ['section', 'lines', 'alternate', 'tracks', 'exception']
#
# word: path
# closest API embedding:   ['list', 'info', 'image', 'uri', 'metadata']
# closest GloVe embedding: ['view', 'point', 'link', 'main', 'flow']
#
# word: key
# closest API embedding:   ['time', 'status', 'type', 'count', 'start']
# closest GloVe embedding: ['set', 'main', 'to', 'target', 'end']
#
# word: email
# closest API embedding:   ['address', 'last', 'details', 'order', 'created']
# closest GloVe embedding: ['addresses', 'messages', 'e', 'user', 'web']
#
# word: phone
# closest API embedding:   ['customer', 'currency', 'amount', 'country', 'transaction']
# closest GloVe embedding: ['customer', 'messages', 'users', 'web', 'contact']
#
# word: code
# closest API embedding:   ['type', 'group', 'name', 'error', 'id']
# closest GloVe embedding: ['reference', 'instance', 'exception', 'file', 'type']
#
# word: detail
# closest API embedding:   ['latest', 'additional', 'of', 'in', 'available']
# closest GloVe embedding: ['details', 'description', 'instance', 'presentation', 'reference']
#
# word: error
# closest API embedding:   ['group', 'code', 'message', 'id', 'details']
# closest GloVe embedding: ['errors', 'calculation', 'result', 'point', 'instance']
#
# word: field
# closest API embedding:   ['country', 'item', 'language', 'color', 'number']
# closest GloVe embedding: ['fields', 'time', 'point', 'first', 'managed']
#
# word: is
# closest API embedding:   ['url', 'by', 'last', 'date', 'title']
# closest GloVe embedding: ['has', 'a', 'instance', 'of', 'name']
#
# word: master
# closest API embedding:   ['permissions', 'event', 'events', 'users', 'view']
# closest GloVe embedding: ['created', 'class', 'instance', 'first', 'artist']
#
# word: link
# closest API embedding:   ['location', 'target', 'value', 'groups', 'display']
# closest GloVe embedding: ['links', 'instance', 'main', 'source', 'location']
#
# word: x
# closest API embedding:   ['service', 'token', 'tags', 'max', 'results']
# closest GloVe embedding: ['type', 'category', 'b', 'c', 'u']
#
# word: messages
# closest API embedding:   ['fields', 'columns', 'users', 'view', 'class']
# closest GloVe embedding: ['message', 'addresses', 'email', 'phone', 'text']
#
# word: start
# closest API embedding:   ['end', 'time', 'key', 'data', 'status']
# closest GloVe embedding: ['next', 'time', 'end', 'set', 'to']
#
# word: end
# closest API embedding:   ['start', 'language', 'source', 'time', 'data']
# closest GloVe embedding: ['next', 'start', 'time', 'set', 'to']
#
# word: client
# closest API embedding:   ['request', 'action', 'account', 'settings', 'email']
# closest GloVe embedding: ['instance', 'customer', 'billing', 'charge', 'contact']
#
# word: data
# closest API embedding:   ['description', 'status', 'source', 'state', 'from']
# closest GloVe embedding: ['tracking', 'account', 'source', 'user', 'available']
#
# word: web
# closest API embedding:   ['users', 'uri', 'view', 'display', 'permissions']
# closest GloVe embedding: ['users', 'media', 'user', 'addresses', 'sites']
#
# word: token
# closest API embedding:   ['service', 'filter', 'max', 'next', 'results']
# closest GloVe embedding: ['expense', 'balances', 'exception', 'ticket', 'tab']
#
# word: subscriptions
# closest API embedding:   ['properties', 'link', 'target', 'resource', 'microsoft']
# closest GloVe embedding: ['subscription', 'billing', 'debit', 'addresses', 'purchases']
#
# word: device
# closest API embedding:   ['list', 'info', 'uri', 'locations', 'update']
# closest GloVe embedding: ['embedded', 'type', 'method', 'link', 'instance']
#
# word: update
# closest API embedding:   ['policy', 'info', 'list', 'request', 'configuration']
# closest GloVe embedding: ['updated', 'latest', 'date', 'info', 'sets']
#
# word: time
# closest API embedding:   ['key', 'start', 'display', 'type', 'location']
# closest GloVe embedding: ['next', 'start', 'to', 'set', 'end']
#
# word: api
# closest API embedding:   ['version', 'id', 'resource', 'name', 'providers']
# closest GloVe embedding: ['app', 'embedded', 'filter', 'metadata', 'user']
#
# word: address
# closest API embedding:   ['email', 'number', 'details', 'last', 'country']
# closest GloVe embedding: ['addresses', 'message', 'speech', 'response', 'instance']
#
# word: number
# closest API embedding:   ['of', 'country', 'order', 'category', 'data']
# closest GloVe embedding: ['other', 'list', 'included', 'instance', 'additional']
#
# word: country
# closest API embedding:   ['number', 'category', 'of', 'order', 'currency']
# closest GloVe embedding: ['has', 'in', 'of', 'to', 'end']
#
# word: currency
# closest API embedding:   ['amount', 'payment', 'price', 'phone', 'transaction']
# closest GloVe embedding: ['credit', 'bank', 'price', 'assets', 'purchases']
#
# word: color
# closest API embedding:   ['language', 'custom', 'field', 'text', 'point']
# closest GloVe embedding: ['image', 'picture', 'display', 'images', 'size']
#
# word: group
# closest API embedding:   ['message', 'error', 'id', 'code', 'name']
# closest GloVe embedding: ['groups', 'other', 'parent', 'by', 'main']
#
# word: count
# closest API embedding:   ['size', 'key', 'url', 'to', 'page']
# closest GloVe embedding: ['instance', 'exception', 'charge', 'result', 'expense']
#
# word: details
# closest API embedding:   ['code', 'error', 'value', 'state', 'address']
# closest GloVe embedding: ['detail', 'description', 'account', 'sources', 'latest']
#
# word: groups
# closest API embedding:   ['message', 'target', 'link', 'group', 'id']
# closest GloVe embedding: ['other', 'group', 'community', 'country', 'action']
#
# word: row
# closest API embedding:   ['rows', 'class', 'modules', 'translated', 'fields']
# closest GloVe embedding: ['set', 'end', 'next', 'exception', 'sets']
#
# word: size
# closest API embedding:   ['count', 'default', 'user', 'tag', 'parent']
# closest GloVe embedding: ['instance', 'type', 'value', 'exception', 'object']
#
# word: batch
# closest API embedding:   ['entity', 'reference', 'addresses', 'quote', 'alias']
# closest GloVe embedding: ['available', 'instance', 'included', 'additional', 'orders']
#
# word: chart
# closest API embedding:   ['special', 'section', 'sources', 'draft', 'color']
# closest GloVe embedding: ['tracks', 'album', 'category', 'list', 'label']
#
# word: first
# closest API embedding:   ['category', 'rate', 'total', 'order', 'of']
# closest GloVe embedding: ['time', 'in', 'following', 'next', 'set']
#
# word: next
# closest API embedding:   ['id', 'type', 'token', 'name', 'group']
# closest GloVe embedding: ['start', 'time', 'end', 'set', 'last']
#
# word: location
# closest API embedding:   ['value', 'link', 'time', 'target', 'display']
# closest GloVe embedding: ['locations', 'link', 'instance', 'sites', 'exception']
#
# word: rate
# closest API embedding:   ['first', 'category', 'notes', 'price', 'line']
# closest GloVe embedding: ['price', 'target', 'credit', 'result', 'value']
#
# word: object
# closest API embedding:   ['options', 'tier', 'card', 'billing', 'reference']
# closest GloVe embedding: ['relation', 'instance', 'element', 'view', 'reference']
#
# word: config
# closest API embedding:   ['instance', 'configuration', 'resources', 'settings', 'request']
# closest GloVe embedding: ['whitelist', 'availabilities', 'attachments', 'infos', 'spec']
#
# word: service
# closest API embedding:   ['token', 'x', 'max', 'next', 'results']
# closest GloVe embedding: ['available', 'special', 'customer', 'contact', 'program']
#
# word: default
# closest API embedding:   ['file', 'size', 'user', 'is', 'content']
# closest GloVe embedding: ['credit', 'payment', 'option', 'file', 'exception']
#
# word: url
# closest API embedding:   ['created', 'last', 'is', 'by', 'date']
# closest GloVe embedding: ['metadata', 'addresses', 'template', 'tags', 'id']
#
# word: i
# closest API embedding:   ['e', 'date', 'd', 'last', 'details']
# closest GloVe embedding: ['kind', 'time', 'to', 'away', 'play']
#
# word: d
# closest API embedding:   ['number', 'country', 'i', 'of', 'order']
# closest GloVe embedding: ['instance', 'exception', 'e', 'x', 'b']
#
# word: alias
# closest API embedding:   ['batch', 'resources', 'uuid', 'settings', 'schedule']
# closest GloVe embedding: ['sid', 'creator', 'spec', 'avatar', 'meta']
#
# word: attributes
# closest API embedding:   ['entity', 'owner', 'errors', 'links', 'x']
# closest GloVe embedding: ['relation', 'instance', 'exception', 'values', 'description']
#
# word: entity
# closest API embedding:   ['attributes', 'product', 'tracking', 'batch', 'included']
# closest GloVe embedding: ['element', 'parent', 'relation', 'status', 'assets']
#
# word: u
# closest API embedding:   ['contact', 'c', 'content', 'email', 'attachments']
# closest GloVe embedding: ['x', 'spec', 'exception', 'note', 'b']
#
# word: format
# closest API embedding:   ['point', 'language', 'start', 'end', 'b']
# closest GloVe embedding: ['version', 'updated', 'versions', 'broadcast', 'content']
#
# word: method
# closest API embedding:   ['from', 'of', 'payment', 'latest', 'amount']
# closest GloVe embedding: ['calculation', 'instance', 'parameters', 'description', 'template']
#
# word: uri
# closest API embedding:   ['list', 'path', 'info', 'users', 'web']
# closest GloVe embedding: ['meta', 'spec', 'sid', 'alias', 'tab']
#
# word: template
# closest API embedding:   ['label', 'result', 'image', 'event', 'path']
# closest GloVe embedding: ['setup', 'element', 'alternate', 'embedded', 'tags']
#
# word: modified
# closest API embedding:   ['content', 'app', 'parent', 'display', 'is']
# closest GloVe embedding: ['type', 'instance', 'versions', 'exception', 'custom']
#
# word: max
# closest API embedding:   ['results', 'token', 'service', 'source', 'set']
# closest GloVe embedding: ['instance', 'created', 'creator', 'sid', 'sets']
#
# word: setup
# closest API embedding:   ['shipping', 'charges', 'mandate', 'debit', 'charge']
# closest GloVe embedding: ['configuration', 'option', 'template', 'tab', 'settings']
#
# word: file
# closest API embedding:   ['default', 'owner', 'has', 'links', 'user']
# closest GloVe embedding: ['client', 'addresses', 'card', 'code', 'instance']
#
# word: pid
# closest API embedding:   ['speech', 'clip', 'broadcast', 'affected', 'presentation']
# closest GloVe embedding: ['setup', 'localized', 'config', 'tab', 'attachments']
#
# word: properties
# closest API embedding:   ['subscriptions', 'resource', 'link', 'microsoft', 'providers']
# closest GloVe embedding: ['locations', 'instance', 'value', 'assets', 'created']
#
# word: set
# closest API embedding:   ['availability', 'result', 'metadata', 'max', 'results']
# closest GloVe embedding: ['sets', 'next', 'time', 'end', 'to']
#
# word: repository
# closest API embedding:   ['repositories', 'repo', 'versions', 'slug', 'master']
# closest GloVe embedding: ['repositories', 'metadata', 'template', 'resource', 'embedded']
#
# word: tags
# closest API embedding:   ['filter', 'token', 'service', 'x', 'count']
# closest GloVe embedding: ['id', 'template', 'item', 'embedded', 'tab']
#
# word: tier
# closest API embedding:   ['object', 'update', 'options', 'values', 'info']
# closest GloVe embedding: ['tag', 'class', 'list', 'category', 'exception']
#
# word: reference
# closest API embedding:   ['schedule', 'currency', 'transaction', 'contact', 'options']
# closest GloVe embedding: ['description', 'instance', 'note', 'text', 'source']
#
# word: bank
# closest API embedding:   ['invoice', 'transactions', 'tax', 'payments', 'fee']
# closest GloVe embedding: ['credit', 'assets', 'currency', 'to', 'charge']
#
# word: schedule
# closest API embedding:   ['reference', 'label', 'option', 'fields', 'batch']
# closest GloVe embedding: ['start', 'scheduled', 'next', 'time', 'date']
#
# word: accounts
# closest API embedding:   ['errors', 'account', 'customer', 'email', 'contact']
# closest GloVe embedding: ['account', 'claims', 'assets', 'transactions', 'expense']
#
# word: merchant
# closest API embedding:   ['shipping', 'fee', 'card', 'billing', 'debit']
# closest GloVe embedding: ['shipping', 'owner', 'managed', 'parent', 'master']
#
# word: to
# closest API embedding:   ['in', 'url', 'total', 'status', 'created']
# closest GloVe embedding: ['from', 'time', 'allowed', 'next', 'set']
#
# word: date
# closest API embedding:   ['last', 'by', 'url', 'is', 'title']
# closest GloVe embedding: ['following', 'exception', 'next', 'set', 'instance']
#
# word: tax
# closest API embedding:   ['invoice', 'discount', 'bank', 'amount', 'payments']
# closest GloVe embedding: ['payments', 'money', 'expense', 'credit', 'fees']
#
# word: contact
# closest API embedding:   ['addresses', 'note', 'reference', 'transaction', 'u']
# closest GloVe embedding: ['instance', 'allowed', 'link', 'to', 'source']
#
# word: instance
# closest API embedding:   ['configuration', 'config', 'list', 'kind', 'uri']
# closest GloVe embedding: ['exception', 'created', 'reference', 'is', 'included']
#
# word: balances
# closest API embedding:   ['invoices', 'persons', 'supplier', 'transactions', 'allocations']
# closest GloVe embedding: ['expense', 'allocations', 'billing', 'credit', 'account']
#
# word: available
# closest API embedding:   ['in', 'method', 'detail', 'set', 'result']
# closest GloVe embedding: ['instance', 'additional', 'product', 'options', 'content']
#
# word: payment
# closest API embedding:   ['amount', 'currency', 'price', 'customer', 'tax']
# closest GloVe embedding: ['payments', 'fees', 'cash', 'expense', 'option']
#
# word: has
# closest API embedding:   ['items', 'item', 'file', 'category', 'default']
# closest GloVe embedding: ['by', 'is', 'in', 'of', 'last']
#
# word: card
# closest API embedding:   ['price', 'currency', 'shipping', 'latest', 'fee']
# closest GloVe embedding: ['tag', 'item', 'ticket', 'tab', 'billing']
#
# word: owner
# closest API embedding:   ['file', 'event', 'settings', 'events', 'default']
# closest GloVe embedding: ['name', 'parent', 'client', 'instance', 'managed']
#
# word: transaction
# closest API embedding:   ['invoice', 'currency', 'amount', 'reference', 'phone']
# closest GloVe embedding: ['transactions', 'payment', 'options', 'account', 'value']
#
# word: amount
# closest API embedding:   ['payment', 'currency', 'customer', 'phone', 'invoice']
# closest GloVe embedding: ['value', 'cash', 'expense', 'account', 'result']
#
# word: transactions
# closest API embedding:   ['bank', 'payments', 'invoices', 'invoice', 'tax']
# closest GloVe embedding: ['transaction', 'accounts', 'assets', 'account', 'purchases']
#
# word: availability
# closest API embedding:   ['set', 'max', 'results', 'metadata', 'result']
# closest GloVe embedding: ['available', 'product', 'exception', 'expense', 'options']
#
# word: brand
# closest API embedding:   ['charge', 'payment', 'fee', 'additional', 'method']
# closest GloVe embedding: ['product', 'branding', 'label', 'supplier', 'custom']
#
# word: orders
# closest API embedding:   ['credit', 'payments', 'transactions', 'bank', 'tracking']
# closest GloVe embedding: ['order', 'charge', 'purchases', 'instance', 'to']
#
# word: order
# closest API embedding:   ['category', 'number', 'updated', 'last', 'first']
# closest GloVe embedding: ['to', 'allowed', 'orders', 'set', 'instance']
#
# word: links
# closest API embedding:   ['self', 'file', 'updated', 'total', 'errors']
# closest GloVe embedding: ['link', 'sites', 'main', 'key', 'addresses']
#
# word: info
# closest API embedding:   ['list', 'update', 'path', 'values', 'language']
# closest GloVe embedding: ['update', 'addresses', 'e', 'id', 'app']
#
# word: billing
# closest API embedding:   ['shipping', 'customer', 'amount', 'currency', 'fee']
# closest GloVe embedding: ['expense', 'customer', 'client', 'instance', 'account']
#
# word: line
# closest API embedding:   ['notes', 'net', 'rate', 'category', 'country']
# closest GloVe embedding: ['lines', 'point', 'main', 'from', 'end']
#
# word: image
# closest API embedding:   ['text', 'custom', 'items', 'template', 'path']
# closest GloVe embedding: ['picture', 'display', 'view', 'images', 'created']
#
# word: product
# closest API embedding:   ['payment', 'method', 'billing', 'amount', 'entity']
# closest GloVe embedding: ['instance', 'sales', 'brand', 'available', 'content']
#
# word: split
# closest API embedding:   ['merchant', 'anchor', 'schedule', 'scheduled', 'bill']
# closest GloVe embedding: ['row', 'end', 'exception', 'instance', 'set']
#
# word: funding
# closest API embedding:   ['refunds', 'debit', 'charges', 'mandate', 'charge']
# closest GloVe embedding: ['program', 'additional', 'contributions', 'expense', 'payments']
#
# word: sources
# closest API embedding:   ['series', 'color', 'special', 'localized', 'web']
# closest GloVe embedding: ['source', 'reference', 'accounts', 'instance', 'details']
#
# word: source
# closest API embedding:   ['data', 'from', 'in', 'end', 'status']
# closest GloVe embedding: ['sources', 'reference', 'instance', 'link', 'is']
#
# word: additional
# closest API embedding:   ['price', 'latest', 'brand', 'of', 'rate']
# closest GloVe embedding: ['available', 'special', 'included', 'number', 'funding']
#
# word: of
# closest API embedding:   ['number', 'country', 'latest', 'from', 'method']
# closest GloVe embedding: ['in', 'from', 'created', 'is', 'instance']
#
# word: quote
# closest API embedding:   ['batch', 'payments', 'invoices', 'addresses', 'anchor']
# closest GloVe embedding: ['note', 'reference', 'notes', 'description', 'page']
#
# word: configuration
# closest API embedding:   ['instance', 'config', 'update', 'service', 'kind']
# closest GloVe embedding: ['setup', 'parameters', 'type', 'modules', 'template']
#
# word: mandate
# closest API embedding:   ['debit', 'funding', 'charges', 'refunds', 'setup']
# closest GloVe embedding: ['option', 'status', 'exception', 'extension', 'request']
#
# word: payments
# closest API embedding:   ['invoices', 'transactions', 'tax', 'bank', 'orders']
# closest GloVe embedding: ['payment', 'fees', 'cash', 'credit', 'tax']
#
# word: from
# closest API embedding:   ['source', 'method', 'data', 'of', 'number']
# closest GloVe embedding: ['in', 'to', 'of', 'by', 'time']
#
# word: total
# closest API embedding:   ['in', 'updated', 'title', 'to', 'first']
# closest GloVe embedding: ['number', 'amount', 'additional', 'value', 'of']
#
# word: list
# closest API embedding:   ['uri', 'info', 'kind', 'path', 'update']
# closest GloVe embedding: ['number', 'names', 'included', 'exception', 'instance']
#
# word: page
# closest API embedding:   ['count', 'url', 'user', 'to', 'created']
# closest GloVe embedding: ['pages', 'addresses', 'notes', 'reference', 'web']
#
# word: a
# closest API embedding:   ['at', 'by', 'status', 'key', 'title']
# closest GloVe embedding: ['is', 'first', 'of', 'in', 'kind']
#
# word: c
# closest API embedding:   ['notes', 'attachments', 'has', 'contact', 'order']
# closest GloVe embedding: ['b', 'x', 'u', 'instance', 'exception']
#
# word: e
# closest API embedding:   ['i', 'display', 'details', 'time', 'date']
# closest GloVe embedding: ['email', 'page', 'web', 'info', 'messages']
#
# word: event
# closest API embedding:   ['events', 'users', 'default', 'owner', 'settings']
# closest GloVe embedding: ['events', 'venue', 'time', 'next', 'set']
#
# word: response
# closest API embedding:   ['settings', 'reference', 'users', 'extension', 'contact']
# closest GloVe embedding: ['warning', 'action', 'result', 'latest', 'speech']
#
# word: b
# closest API embedding:   ['format', 'd', 'a', 'data', 'state']
# closest GloVe embedding: ['c', 'x', 'u', 'exception', 'instance']
#
# word: results
# closest API embedding:   ['max', 'token', 'service', 'metadata', 'set']
# closest GloVe embedding: ['result', 'date', 'following', 'events', 'event']
#
# word: credit
# closest API embedding:   ['orders', 'tracking', 'payment', 'price', 'payments']
# closest GloVe embedding: ['cash', 'payments', 'money', 'expense', 'account']
#
# word: values
# closest API embedding:   ['info', 'path', 'template', 'list', 'update']
# closest GloVe embedding: ['relation', 'value', 'attributes', 'view', 'instance']
#
# word: users
# closest API embedding:   ['view', 'event', 'uri', 'default', 'custom']
# closest GloVe embedding: ['user', 'web', 'providers', 'available', 'phone']
#
# word: metadata
# closest API embedding:   ['set', 'path', 'max', 'count', 'results']
# closest GloVe embedding: ['repositories', 'template', 'url', 'repository', 'embedded']
#
# word: parameters
# closest API embedding:   ['policy', 'state', 'action', 'update', 'data']
# closest GloVe embedding: ['calculation', 'relation', 'coordinates', 'method', 'template']
#
# word: notes
# closest API embedding:   ['line', 'category', 'rate', 'first', 'net']
# closest GloVe embedding: ['note', 'reference', 'instance', 'page', 'account']
#
# word: tag
# closest API embedding:   ['size', 'filter', 'count', 'key', 'path']
# closest GloVe embedding: ['card', 'tier', 'tab', 'tags', 'exception']
#
# word: localized
# closest API embedding:   ['program', 'main', 'point', 'sources', 'alternate']
# closest GloVe embedding: ['cluster', 'affected', 'instance', 'embedded', 'exception']
#
# word: subscription
# closest API embedding:   ['providers', 'resource', 'api', 'version', 'group']
# closest GloVe embedding: ['subscriptions', 'billing', 'fee', 'fees', 'payment']
#
# word: release
# closest API embedding:   ['images', 'related', 'author', 'media', 'href']
# closest GloVe embedding: ['date', 'latest', 'by', 'following', 'request']
#
# word: shipping
# closest API embedding:   ['fee', 'billing', 'charge', 'setup', 'debit']
# closest GloVe embedding: ['purchases', 'merchant', 'supplier', 'routes', 'service']
#
# word: language
# closest API embedding:   ['end', 'info', 'start', 'text', 'custom']
# closest GloVe embedding: ['reference', 'translated', 'text', 'instance', 'description']
#
# word: images
# closest API embedding:   ['release', 'versions', 'metadata', 'sets', 'media']
# closest GloVe embedding: ['display', 'image', 'picture', 'color', 'detail']
#
# word: permissions
# closest API embedding:   ['master', 'event', 'view', 'events', 'users']
# closest GloVe embedding: ['billing', 'metadata', 'balances', 'repositories', 'addresses']
#
# word: in
# closest API embedding:   ['total', 'to', 'source', 'from', 'title']
# closest GloVe embedding: ['from', 'of', 'first', 'following', 'to']
#
# word: errors
# closest API embedding:   ['to', 'links', 'updated', 'created', 'account']
# closest GloVe embedding: ['error', 'result', 'billing', 'instance', 'detail']
#
# word: text
# closest API embedding:   ['image', 'custom', 'items', 'language', 'end']
# closest GloVe embedding: ['reference', 'translated', 'addresses', 'page', 'description']
#
# word: author
# closest API embedding:   ['media', 'release', 'images', 'play', 'thumb']
# closest GloVe embedding: ['artist', 'translated', 'creator', 'instance', 'reference']
#
# word: names
# closest API embedding:   ['values', 'uri', 'master', 'path', 'template']
# closest GloVe embedding: ['instance', 'name', 'list', 'other', 'included']
#
# word: charge
# closest API embedding:   ['fee', 'charges', 'funding', 'refunds', 'debit']
# closest GloVe embedding: ['charges', 'instance', 'to', 'claims', 'exception']
#
# word: sets
# closest API embedding:   ['affected', 'images', 'set', 'available', 'element']
# closest GloVe embedding: ['set', 'instance', 'row', 'exception', 'allowed']
#
# word: relationships
# closest API embedding:   ['rel', 'meta', 'href', 'attributes', 'entity']
# closest GloVe embedding: ['relation', 'instance', 'parent', 'contact', 'related']
#
# word: style
# closest API embedding:   ['shares', 'series', 'picture', 'master', 'creator']
# closest GloVe embedding: ['popular', 'theme', 'kind', 'custom', 'elements']
#
# word: streams
# closest API embedding:   ['codec', 'series', 'artist', 'sources', 'community']
# closest GloVe embedding: ['flow', 'fields', 'localized', 'sections', 'tracks']
#
# word: latest
# closest API embedding:   ['of', 'method', 'from', 'additional', 'card']
# closest GloVe embedding: ['last', 'response', 'following', 'key', 'action']
#
# word: repo
# closest API embedding:   ['repository', 'repositories', 'slug', 'avatar', 'versions']
# closest GloVe embedding: ['discount', 'transaction', 'invoice', 'balances', 'rate']
#
# word: option
# closest API embedding:   ['scheduled', 'other', 'allowed', 'schedule', 'class']
# closest GloVe embedding: ['options', 'exception', 'allowed', 'instance', 'extension']
#
# word: customer
# closest API embedding:   ['amount', 'billing', 'phone', 'payment', 'currency']
# closest GloVe embedding: ['parent', 'billing', 'client', 'options', 'expense']
#
# word: display
# closest API embedding:   ['time', 'location', 'content', 'modified', 'is']
# closest GloVe embedding: ['image', 'images', 'presentation', 'picture', 'instance']
#
# word: slug
# closest API embedding:   ['repositories', 'avatar', 'repo', 'repository', 'following']
# closest GloVe embedding: ['update', 'quote', 'tags', 'info', 'reference']
#
# word: self
# closest API embedding:   ['links', 'page', 'pages', 'parent', 'file']
# closest GloVe embedding: ['kind', 'intent', 'view', 'image', 'a']
#
# word: embedded
# closest API embedding:   ['purchases', 'href', 'rel', 'rate', 'persons']
# closest GloVe embedding: ['device', 'cluster', 'template', 'instance', 'object']
#
# word: parent
# closest API embedding:   ['app', 'modified', 'content', 'user', 'size']
# closest GloVe embedding: ['customer', 'instance', 'client', 'entity', 'group']
#
# word: main
# closest API embedding:   ['program', 'infos', 'allowed', 'alternate', 'class']
# closest GloVe embedding: ['of', 'key', 'in', 'link', 'is']
#
# word: media
# closest API embedding:   ['author', 'text', 'series', 'images', 'release']
# closest GloVe embedding: ['web', 'by', 'broadcast', 'source', 'has']
#
# word: assets
# closest API embedding:   ['popular', 'theme', 'purchases', 'avatar', 'self']
# closest GloVe embedding: ['accounts', 'value', 'cash', 'transactions', 'money']
#
# word: target
# closest API embedding:   ['link', 'message', 'value', 'groups', 'location']
# closest GloVe embedding: ['key', 'charge', 'option', 'instance', 'to']
#
# word: allowed
# closest API embedding:   ['custom', 'other', 'text', 'option', 'items']
# closest GloVe embedding: ['to', 'managed', 'set', 'time', 'order']
#
# word: options
# closest API embedding:   ['object', 'address', 'info', 'latest', 'currency']
# closest GloVe embedding: ['option', 'instance', 'available', 'purchases', 'customer']
#
# word: extension
# closest API embedding:   ['creator', 'recipients', 'response', 'addresses', 'owner']
# closest GloVe embedding: ['option', 'exception', 'end', 'line', 'link']
#
# word: draft
# closest API embedding:   ['section', 'teams', 'coordinates', 'special', 'attachments']
# closest GloVe embedding: ['mandate', 'list', 'exception', 'bill', 'date']
#
# word: class
# closest API embedding:   ['fields', 'item', 'row', 'option', 'custom']
# closest GloVe embedding: ['type', 'instance', 'category', 'exception', 'tier']
#
# word: included
# closest API embedding:   ['entity', 'orders', 'warnings', 'credit', 'product']
# closest GloVe embedding: ['created', 'by', 'other', 'instance', 'special']
#
# word: price
# closest API embedding:   ['currency', 'payment', 'additional', 'amount', 'rate']
# closest GloVe embedding: ['sales', 'value', 'purchases', 'discount', 'rate']
#
# word: fees
# closest API embedding:   ['refunds', 'charges', 'debit', 'fee', 'mandate']
# closest GloVe embedding: ['payments', 'payment', 'fee', 'expense', 'cash']
#
# word: seat
# closest API embedding:   ['module', 'modules', 'infos', 'ticket', 'route']
# closest GloVe embedding: ['exception', 'split', 'ticket', 'next', 'row']
#
# word: locations
# closest API embedding:   ['device', 'messages', 'uri', 'list', 'web']
# closest GloVe embedding: ['location', 'sites', 'available', 'instance', 'sections']
#
# word: meta
# closest API embedding:   ['href', 'errors', 'page', 'links', 'available']
# closest GloVe embedding: ['uri', 'sid', 'alias', 'spec', 'info']
#
# word: warnings
# closest API embedding:   ['included', 'available', 'credit', 'href', 'rel']
# closest GloVe embedding: ['warning', 'response', 'latest', 'orders', 'affected']
#
# error: word amz is not embedded
# word: amz
# closest API embedding:   ['cluster', 'service', 'subscription', 'version', 'configuration']
# closest GloVe embedding: rror:
#
# word: resources
# closest API embedding:   ['config', 'settings', 'instance', 'request', 'device']
# closest GloVe embedding: ['resource', 'fields', 'source', 'contributions', 'managed']
#
# word: policy
# closest API embedding:   ['update', 'action', 'state', 'service', 'max']
# closest GloVe embedding: ['action', 'key', 'response', 'view', 'address']
#
# word: events
# closest API embedding:   ['event', 'versions', 'owner', 'file', 'master']
# closest GloVe embedding: ['event', 'venue', 'series', 'time', 'theme']
#
# word: meeting
# closest API embedding:   ['coordinates', 'calendar', 'sites', 'section', 'view']
# closest GloVe embedding: ['scheduled', 'next', 'key', 'speech', 'last']
#
# word: addresses
# closest API embedding:   ['contact', 'batch', 'response', 'quote', 'extension']
# closest GloVe embedding: ['address', 'instance', 'messages', 'page', 'reference']
#
# word: calendar
# closest API embedding:   ['coordinates', 'meeting', 'view', 'attachments', 'sites']
# closest GloVe embedding: ['date', 'updated', 'addresses', 'item', 'reference']
#
# word: providers
# closest API embedding:   ['microsoft', 'subscription', 'api', 'resource', 'properties']
# closest GloVe embedding: ['users', 'customer', 'billing', 'expense', 'phone']
#
# word: spec
# closest API embedding:   ['config', 'resources', 'alias', 'routes', 'uuid']
# closest GloVe embedding: ['sid', 'template', 'tab', 'config', 'setup']
#
# word: custom
# closest API embedding:   ['image', 'text', 'items', 'allowed', 'fields']
# closest GloVe embedding: ['instance', 'settings', 'versions', 'style', 'display']
#
# word: app
# closest API embedding:   ['parent', 'modified', 'content', 'user', 'groups']
# closest GloVe embedding: ['user', 'info', 'web', 'users', 'addresses']
#
# word: settings
# closest API embedding:   ['owner', 'event', 'request', 'response', 'client']
# closest GloVe embedding: ['setup', 'instance', 'custom', 'template', 'alternate']
#
# word: claims
# closest API embedding:   ['expense', 'branding', 'elements', 'supplier', 'theme']
# closest GloVe embedding: ['accounts', 'account', 'instance', 'charge', 'exception']
#
# word: cluster
# closest API embedding:   ['configuration', 'kind', 'instance', 'amz', 'config']
# closest GloVe embedding: ['localized', 'embedded', 'instance', 'link', 'element']
#
# word: versions
# closest API embedding:   ['events', 'images', 'event', 'template', 'metadata']
# closest GloVe embedding: ['version', 'available', 'modified', 'custom', 'updated']
#
# word: route
# closest API embedding:   ['table', 'routes', 'translated', 'device', 'tier']
# closest GloVe embedding: ['routes', 'section', 'line', 'transit', 'sections']
#
# word: managed
# closest API embedding:   ['permissions', 'instance', 'subscriptions', 'device', 'resources']
# closest GloVe embedding: ['allowed', 'to', 'away', 'time', 'set']
#
# word: routes
# closest API embedding:   ['table', 'route', 'columns', 'spec', 'translated']
# closest GloVe embedding: ['route', 'transit', 'lines', 'shipping', 'link']
#
# word: flow
# closest API embedding:   ['product', 'included', 'attributes', 'x', 'entity']
# closest GloVe embedding: ['streams', 'amount', 'path', 'result', 'availability']
#
# word: scheduled
# closest API embedding:   ['option', 'other', 'warning', 'allowed', 'label']
# closest GloVe embedding: ['next', 'meeting', 'schedule', 'date', 'last']
#
# word: tracking
# closest API embedding:   ['note', 'credit', 'payments', 'entity', 'contact']
# closest GloVe embedding: ['data', 'target', 'link', 'instance', 'account']
#
# word: related
# closest API embedding:   ['release', 'href', 'warning', 'images', 'available']
# closest GloVe embedding: ['instance', 'other', 'of', 'account', 'result']
#
# word: view
# closest API embedding:   ['users', 'web', 'permissions', 'master', 'messages']
# closest GloVe embedding: ['instance', 'reference', 'kind', 'point', 'image']
#
# word: transit
# closest API embedding:   ['intent', 'shipping', 'card', 'refunds', 'object']
# closest GloVe embedding: ['routes', 'link', 'extension', 'route', 'service']
#
# word: table
# closest API embedding:   ['route', 'values', 'translated', 'routes', 'tier']
# closest GloVe embedding: ['set', 'row', 'next', 'sets', 'time']
#
# word: kind
# closest API embedding:   ['list', 'update', 'configuration', 'policy', 'instance']
# closest GloVe embedding: ['self', 'instance', 'is', 'a', 'view']
#
# word: point
# closest API embedding:   ['format', 'color', 'language', 'text', 'play']
# closest GloVe embedding: ['time', 'end', 'to', 'view', 'line']
#
# word: creator
# closest API embedding:   ['extension', 'shares', 'view', 'owner', 'event']
# closest GloVe embedding: ['avatar', 'fantasy', 'alias', 'author', 'created']
#
# word: attachments
# closest API embedding:   ['c', 'theme', 'has', 'file', 'u']
# closest GloVe embedding: ['config', 'embedded', 'billing', 'addresses', 'settings']
#
# word: anchor
# closest API embedding:   ['bill', 'quote', 'merchant', 'split', 'alias']
# closest GloVe embedding: ['contact', 'parent', 'broadcast', 'clip', 'service']
#
# word: repositories
# closest API embedding:   ['repository', 'slug', 'repo', 'versions', 'avatar']
# closest GloVe embedding: ['repository', 'metadata', 'embedded', 'template', 'whitelist']
#
# word: infos
# closest API embedding:   ['main', 'module', 'values', 'program', 'tier']
# closest GloVe embedding: ['availabilities', 'whitelist', 'config', 'spec', 'sid']
#
# word: modules
# closest API embedding:   ['module', 'row', 'rows', 'translated', 'main']
# closest GloVe embedding: ['module', 'configuration', 'alternate', 'parameters', 'embedded']
#
# word: exception
# closest API embedding:   ['availability', 'set', 'result', 'tier', 'values']
# closest GloVe embedding: ['instance', 'result', 'relation', 'reference', 'date']
#
# word: elements
# closest API embedding:   ['branding', 'note', 'theme', 'recipients', 'claims']
# closest GloVe embedding: ['element', 'reference', 'created', 'instance', 'relation']
#
# word: columns
# closest API embedding:   ['messages', 'names', 'rows', 'row', 'fields']
# closest GloVe embedding: ['rows', 'sections', 'page', 'pages', 'notes']
#
# word: microsoft
# closest API embedding:   ['providers', 'properties', 'resource', 'subscriptions', 'api']
# closest GloVe embedding: ['client', 'web', 'users', 'file', 'user']
#
# word: warning
# closest API embedding:   ['scheduled', 'contribution', 'related', 'element', 'images']
# closest GloVe embedding: ['warnings', 'response', 'message', 'latest', 'action']
#
# word: net
# closest API embedding:   ['line', 'decimal', 'notes', 'lines', 'discount']
# closest GloVe embedding: ['credit', 'cash', 'account', 'sales', 'value']
#
# word: charges
# closest API embedding:   ['refunds', 'funding', 'charge', 'debit', 'mandate']
# closest GloVe embedding: ['charge', 'claims', 'intent', 'request', 'client']
#
# word: album
# closest API embedding:   ['artist', 'codec', 'thumb', 'genre', 'play']
# closest GloVe embedding: ['band', 'label', 'tracks', 'version', 'release']
#
# word: play
# closest API embedding:   ['season', 'rating', 'point', 'community', 'media']
# closest GloVe embedding: ['game', 'player', 'time', 'start', 'first']
#
# word: codec
# closest API embedding:   ['album', 'artist', 'streams', 'thumb', 'play']
# closest GloVe embedding: ['template', 'app', 'filter', 'api', 'embedded']
#
# word: game
# closest API embedding:   ['away', 'player', 'fantasy', 'venue', 'games']
# closest GloVe embedding: ['games', 'play', 'player', 'season', 'start']
#
# word: player
# closest API embedding:   ['game', 'games', 'away', 'fantasy', 'sports']
# closest GloVe embedding: ['play', 'game', 'title', 'first', 'teams']
#
# word: ticket
# closest API embedding:   ['row', 'modules', 'rows', 'messages', 'columns']
# closest GloVe embedding: ['card', 'item', 'expense', 'token', 'purchases']
#
# word: affected
# closest API embedding:   ['element', 'sets', 'speech', 'availabilities', 'broadcast']
# closest GloVe embedding: ['result', 'related', 'instance', 'country', 'exception']
#
# word: rows
# closest API embedding:   ['row', 'translated', 'class', 'modules', 'fields']
# closest GloVe embedding: ['row', 'sections', 'table', 'columns', 'alternate']
#
# word: clip
# closest API embedding:   ['presentation', 'broadcast', 'speech', 'pid', 'contributions']
# closest GloVe embedding: ['picture', 'presentation', 'item', 'tracking', 'tab']
#
# word: intent
# closest API embedding:   ['funding', 'refunds', 'charges', 'charge', 'debit']
# closest GloVe embedding: ['charge', 'instance', 'self', 'action', 'branding']
#
# word: series
# closest API embedding:   ['sources', 'media', 'community', 'special', 'text']
# closest GloVe embedding: ['first', 'included', 'episode', 'theme', 'events']
#
# word: fee
# closest API embedding:   ['shipping', 'charge', 'debit', 'charges', 'refunds']
# closest GloVe embedding: ['fees', 'payment', 'subscription', 'payments', 'cash']
#
# word: whitelist
# closest API embedding:   ['uuid', 'tab', 'spec', 'routes', 'alias']
# closest GloVe embedding: ['config', 'availabilities', 'infos', 'template', 'url']
#
# word: program
# closest API embedding:   ['main', 'localized', 'alternate', 'point', 'infos']
# closest GloVe embedding: ['funding', 'special', 'extension', 'service', 'policy']
#
# word: special
# closest API embedding:   ['sources', 'color', 'rating', 'teams', 'series']
# closest GloVe embedding: ['included', 'additional', 'instance', 'exception', 'set']
#
# word: presentation
# closest API embedding:   ['broadcast', 'clip', 'contributions', 'element', 'speech']
# closest GloVe embedding: ['detail', 'display', 'picture', 'speech', 'instance']
#
# word: allocations
# closest API embedding:   ['supplier', 'balances', 'invoices', 'persons', 'claims']
# closest GloVe embedding: ['balances', 'expense', 'funding', 'availability', 'contributions']
#
# word: sites
# closest API embedding:   ['meeting', 'calendar', 'locations', 'managed', 'coordinates']
# closest GloVe embedding: ['locations', 'link', 'web', 'location', 'links']
#
# word: theme
# closest API embedding:   ['attachments', 'elements', 'branding', 'formatted', 'note']
# closest GloVe embedding: ['popular', 'created', 'fantasy', 'series', 'view']
#
# word: speech
# closest API embedding:   ['availabilities', 'affected', 'pid', 'clip', 'presentation']
# closest GloVe embedding: ['message', 'response', 'address', 'presentation', 'view']
#
# word: decimal
# closest API embedding:   ['net', 'lines', 'line', 'discount', 'notes']
# closest GloVe embedding: ['calculation', 'template', 'parameters', 'reference', 'code']
#
# word: shares
# closest API embedding:   ['style', 'creator', 'master', 'avatar', 'tab']
# closest GloVe embedding: ['price', 'sales', 'value', 'net', 'parent']
#
# word: lines
# closest API embedding:   ['decimal', 'net', 'line', 'discount', 'calculation']
# closest GloVe embedding: ['line', 'sections', 'main', 'instance', 'link']
#
# word: tracks
# closest API embedding:   ['author', 'popular', 'thumb', 'release', 'artist']
# closest GloVe embedding: ['sections', 'included', 'chart', 'lines', 'number']
#
# word: persons
# closest API embedding:   ['supplier', 'sales', 'balances', 'expense', 'purchases']
# closest GloVe embedding: ['number', 'exception', 'instance', 'affected', 'relation']
#
# word: note
# closest API embedding:   ['tracking', 'contact', 'branding', 'sales', 'discount']
# closest GloVe embedding: ['notes', 'reference', 'quote', 'instance', 'page']
#
# word: other
# closest API embedding:   ['option', 'scheduled', 'allowed', 'additional', 'items']
# closest GloVe embedding: ['included', 'number', 'instance', 'related', 'of']
#
# word: pages
# closest API embedding:   ['self', 'parent', 'c', 'app', 'links']
# closest GloVe embedding: ['page', 'addresses', 'notes', 'text', 'web']
#
# word: translated
# closest API embedding:   ['rows', 'row', 'modules', 'table', 'module']
# closest GloVe embedding: ['text', 'reference', 'notes', 'instance', 'name']
#
# word: invoice
# closest API embedding:   ['tax', 'bank', 'transaction', 'amount', 'customer']
# closest GloVe embedding: ['invoices', 'whitelist', 'debit', 'tags', 'purchases']
#
# word: expense
# closest API embedding:   ['claims', 'branding', 'supplier', 'sales', 'persons']
# closest GloVe embedding: ['account', 'cash', 'exception', 'balances', 'billing']
#
# word: supplier
# closest API embedding:   ['persons', 'expense', 'allocations', 'balances', 'sales']
# closest GloVe embedding: ['product', 'brand', 'shipping', 'customer', 'parent']
#
# word: discount
# closest API embedding:   ['tax', 'invoice', 'line', 'price', 'note']
# closest GloVe embedding: ['purchases', 'price', 'customer', 'options', 'sales']
#
# word: invoices
# closest API embedding:   ['payments', 'transactions', 'bank', 'tax', 'invoice']
# closest GloVe embedding: ['debit', 'refunds', 'billing', 'accounts', 'balances']
#
# word: rel
# closest API embedding:   ['href', 'relationships', 'warnings', 'meta', 'related']
# closest GloVe embedding: ['infos', 'spec', 'quote', 'sid', 'config']
#
# word: bill
# closest API embedding:   ['anchor', 'quote', 'merchant', 'alias', 'split']
# closest GloVe embedding: ['tax', 'policy', 'exception', 'instance', 'draft']
#
# word: refunds
# closest API embedding:   ['debit', 'charges', 'funding', 'charge', 'mandate']
# closest GloVe embedding: ['payment', 'payments', 'invoices', 'fees', 'billing']
#
# word: rating
# closest API embedding:   ['play', 'season', 'point', 'special', 'game']
# closest GloVe embedding: ['credit', 'note', 'category', 'net', 'exception']
#
# word: loan
# closest API embedding:   ['band', 'lines', 'credit', 'brand', 'fees']
# closest GloVe embedding: ['credit', 'payments', 'payment', 'cash', 'funding']
#
# word: popular
# closest API embedding:   ['assets', 'tracks', 'release', 'picture', 'contributions']
# closest GloVe embedding: ['theme', 'included', 'instance', 'style', 'created']
#
# word: sales
# closest API embedding:   ['branding', 'note', 'persons', 'discount', 'payments']
# closest GloVe embedding: ['price', 'product', 'purchases', 'net', 'discount']
#
# word: contribution
# closest API embedding:   ['warning', 'contributions', 'related', 'other', 'element']
# closest GloVe embedding: ['contributions', 'expense', 'exception', 'account', 'attributes']
#
# word: avatar
# closest API embedding:   ['owner', 'events', 'creator', 'slug', 'uuid']
# closest GloVe embedding: ['creator', 'alias', 'picture', 'fantasy', 'tab']
#
# word: formatted
# closest API embedding:   ['theme', 'picture', 'attachments', 'branding', 'assets']
# closest GloVe embedding: ['format', 'embedded', 'template', 'app', 'sections']
#
# word: teams
# closest API embedding:   ['draft', 'special', 'section', 'sections', 'coordinates']
# closest GloVe embedding: ['games', 'player', 'play', 'start', 'managed']
#
# word: band
# closest API embedding:   ['loan', 'brand', 'fees', 'warnings', 'credit']
# closest GloVe embedding: ['album', 'label', 'tracks', 'artist', 'release']
#
# word: fantasy
# closest API embedding:   ['away', 'games', 'opponent', 'game', 'player']
# closest GloVe embedding: ['genre', 'theme', 'series', 'created', 'creator']
#
# word: purchases
# closest API embedding:   ['persons', 'branding', 'sales', 'embedded', 'tracking']
# closest GloVe embedding: ['discount', 'cash', 'expense', 'options', 'sales']
#
# word: alternate
# closest API embedding:   ['program', 'main', 'allowed', 'localized', 'sources']
# closest GloVe embedding: ['exception', 'instance', 'sections', 'template', 'sets']
#
# word: recipients
# closest API embedding:   ['relation', 'extension', 'elements', 'creator', 'addresses']
# closest GloVe embedding: ['contributions', 'funding', 'expense', 'payments', 'additional']
#
# word: season
# closest API embedding:   ['play', 'rating', 'sports', 'game', 'point']
# closest GloVe embedding: ['game', 'games', 'start', 'play', 'first']
#
# word: episode
# closest API embedding:   ['genre', 'artist', 'play', 'album', 'author']
# closest GloVe embedding: ['series', 'picture', 'theme', 'fantasy', 'creator']
#
# word: artist
# closest API embedding:   ['album', 'codec', 'thumb', 'genre', 'episode']
# closest GloVe embedding: ['author', 'genre', 'picture', 'included', 'created']
#
# word: tab
# closest API embedding:   ['recipients', 'shares', 'creator', 'whitelist', 'rows']
# closest GloVe embedding: ['setup', 'card', 'tag', 'tags', 'balances']
#
# word: element
# closest API embedding:   ['affected', 'broadcast', 'presentation', 'warning', 'availabilities']
# closest GloVe embedding: ['elements', 'relation', 'reference', 'type', 'instance']
#
# word: sid
# closest API embedding:   ['meta', 'results', 'pid', 'tags', 'token']
# closest GloVe embedding: ['alias', 'spec', 'meta', 'creator', 'branding']
#
# word: module
# closest API embedding:   ['modules', 'infos', 'main', 'row', 'rows']
# closest GloVe embedding: ['modules', 'configuration', 'embedded', 'setup', 'device']
#
# word: availabilities
# closest API embedding:   ['speech', 'affected', 'element', 'sets', 'presentation']
# closest GloVe embedding: ['infos', 'whitelist', 'config', 'branding', 'attachments']
#
# word: branding
# closest API embedding:   ['expense', 'note', 'sales', 'elements', 'claims']
# closest GloVe embedding: ['brand', 'intent', 'self', 'exception', 'instance']
#
# word: thumb
# closest API embedding:   ['album', 'artist', 'community', 'play', 'author']
# closest GloVe embedding: ['embedded', 'setup', 'tab', 'row', 'tag']
#
# word: calculation
# closest API embedding:   ['cash', 'discount', 'lines', 'option', 'credit']
# closest GloVe embedding: ['method', 'parameters', 'relation', 'attributes', 'instance']
#
# word: venue
# closest API embedding:   ['game', 'away', 'player', 'sports', 'point']
# closest GloVe embedding: ['event', 'events', 'main', 'exception', 'scheduled']
#
# word: genre
# closest API embedding:   ['episode', 'artist', 'play', 'album', 'author']
# closest GloVe embedding: ['fantasy', 'theme', 'style', 'elements', 'popular']
#
# word: contributions
# closest API embedding:   ['broadcast', 'presentation', 'clip', 'contribution', 'element']
# closest GloVe embedding: ['contribution', 'expense', 'account', 'accounts', 'recipients']
#
# word: broadcast
# closest API embedding:   ['presentation', 'contributions', 'element', 'clip', 'affected']
# closest GloVe embedding: ['media', 'format', 'release', 'service', 'special']
#
# word: picture
# closest API embedding:   ['formatted', 'community', 'style', 'series', 'theme']
# closest GloVe embedding: ['image', 'view', 'presentation', 'detail', 'images']
#
# word: money
# closest API embedding:   ['venue', 'away', 'decimal', 'net', 'field']
# closest GloVe embedding: ['cash', 'credit', 'expense', 'tax', 'payments']
#
# word: following
# closest API embedding:   ['master', 'series', 'permissions', 'view', 'slug']
# closest GloVe embedding: ['in', 'first', 'result', 'end', 'last']
#
# word: cash
# closest API embedding:   ['calculation', 'discount', 'payments', 'invoices', 'credit']
# closest GloVe embedding: ['money', 'payments', 'credit', 'expense', 'payment']
#
# word: debit
# closest API embedding:   ['mandate', 'refunds', 'funding', 'charges', 'fee']
# closest GloVe embedding: ['invoices', 'billing', 'tags', 'card', 'purchases']
#
# word: community
# closest API embedding:   ['thumb', 'series', 'play', 'artist', 'special']
# closest GloVe embedding: ['country', 'of', 'main', 'groups', 'view']
#
# word: relation
# closest API embedding:   ['recipients', 'elements', 'addresses', 'quote', 'extension']
# closest GloVe embedding: ['attributes', 'exception', 'instance', 'element', 'reference']
#
# word: coordinates
# closest API embedding:   ['calendar', 'meeting', 'section', 'draft', 'view']
# closest GloVe embedding: ['parameters', 'relation', 'element', 'tracking', 'url']
#
# word: games
# closest API embedding:   ['opponent', 'fantasy', 'away', 'player', 'game']
# closest GloVe embedding: ['game', 'season', 'play', 'series', 'teams']
#
# word: away
# closest API embedding:   ['fantasy', 'game', 'games', 'player', 'opponent']
# closest GloVe embedding: ['managed', 'to', 'time', 'from', 'start']
#
# word: opponent
# closest API embedding:   ['games', 'fantasy', 'away', 'player', 'game']
# closest GloVe embedding: ['row', 'exception', 'managed', 'allowed', 'set']
#
# word: sports
# closest API embedding:   ['season', 'player', 'venue', 'play', 'game']
# closest GloVe embedding: ['media', 'venue', 'popular', 'events', 'games']
